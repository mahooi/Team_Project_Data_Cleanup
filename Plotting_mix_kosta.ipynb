# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/kosta/github-tests/butter_team_project'

# %%
mix = pd.read_csv('/Users/kosta/github-tests/butter_team_project/sql_merged_data/mix_2020_final.csv')

# %%
mix.plot()
