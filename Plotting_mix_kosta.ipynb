# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
pwd
# Out:
# '/Users/kosta/github-tests/butter_team_project/sql_merged_data'

# %%
mix = pd.read_csv('/Users/kosta/github-tests/butter_team_project/sql_merged_data/mix_2020_final_percent.csv')

# %%
pd.set_option('display.max_rows', 500)
mix
# Out:
#                     Date  Coal_percentage  Cogeneration_percentage  \
# 0    2020-01-01 00:00:00         0.014501                 0.098684
# 1    2020-01-02 00:00:00         0.019112                 0.104008
# 2    2020-01-03 00:00:00         0.021881                 0.118552
# 3    2020-01-04 00:00:00         0.022238                 0.114957
# 4    2020-01-05 00:00:00         0.031245                 0.123728
# 5    2020-01-06 00:00:00         0.025305                 0.126782
# 6    2020-01-07 00:00:00         0.031140                 0.115193
# 7    2020-01-08 00:00:00         0.038541                 0.117176
# 8    2020-01-09 00:00:00         0.036569                 0.111889
# 9    2020-01-10 00:00:00         0.044690                 0.108054
# 10   2020-01-11 00:00:00         0.052316                 0.118239
# 11   2020-01-12 00:00:00         0.053708                 0.118194
# 12   2020-01-13 00:00:00         0.047610                 0.104712
# ...

# %%
mix["Wind_percentage"].plot()

# %%
mix.columns
# Out:
# Index(['Date', 'Coal_percentage', 'Cogeneration_percentage',
#        'Combined_Cycle_percentage', 'Gas_percentage', 'Hydro_percentage',
#        'Hydroeolian_percentage', 'Non_Renewable_Waste_percentage',
#        'Nuclear_percentage', 'Other_Renewables_percentage',
#        'Solar_photovoltaic_percentage', 'Pumped_storage_percentage',
#        'Renewable_Waste_percentage', 'Thermal_Solar_percentage',
#        'Wind_percentage'],
#       dtype='object')

# %%
0.013949 + 0.014541 + 0.008382 + 0.015948 + 0.034423 + 0.012684 + 0.003183 + 0.001065
# Out:
# 0.10417500000000002

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Other', 'Cogeneration', 'Combined_Cycle', 'Hydro', 'Non_Renewable_Waste', 'Wind'
sizes = 0.10417500000000002,0.086242, 0.053062, 0.078637, 0.171436, 0.506379

fig1, ax1 = plt.subplots(figsize = [10,10])
plt.title("""Energy mix by type on the 1st of March 2020
""")
mpl.rcParams['font.size'] = 14.0
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
(0.023909 + 0.016144 + 0.008035 + 0.019403 + 0.022008 + 0.002412 + 0.008864)
# Out:
# 0.10077499999999999

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Other', 'Cogeneration', 'Combined_Cycle', 'Hydro', 'Nuclear', 'Solar_photovoltaic', 'Wind'
sizes = 0.10077499999999999, 0.112883, 0.148365, 0.150841, 0.285726, 0.055272, 0.146114

fig1, ax1 = plt.subplots(figsize = [10,10])
plt.title("""Energy mix by type on the 1st of April 2020
""")
mpl.rcParams['font.size'] = 14.0
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
