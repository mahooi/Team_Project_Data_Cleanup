# %% [markdown]
# Figure 1: Lockdown Vs. Demand Evolution

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/Users/ibsi/Desktop/Ironhack/butter_team_project/sql_merged_data/sh_dem_2020_no_dup.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#     Country                 Date   Value  Status  \
# 0     Spain  2020-01-01 00:00:00  574721       0
# 1     Spain  2020-01-02 00:00:00  723478       0
# 2     Spain  2020-01-03 00:00:00  754804       0
# 3     Spain  2020-01-04 00:00:00  702360       0
# 4     Spain  2020-01-05 00:00:00  651928       0
# ..      ...                  ...     ...     ...
# 158   Spain  2020-06-07 00:00:00  538702       1
# 159   Spain  2020-06-08 00:00:00  623672       1
# 160   Spain  2020-06-09 00:00:00  644278       1
# 161   Spain  2020-06-10 00:00:00  655647       1
# 162   Spain  2020-06-11 00:00:00  652471       1
#
#                             Description
# 0                           No measures
# 1                           No measures
# 2                           No measures
# 3                           No measures
# 4                           No measures
# ..                                  ...
# 158  Recommended not to leave the house
# 159  Recommended not to leave the house
# ...

# %%
Demand_plot = df.loc[data["Country"] == "Spain"]
fig, ax = plt.subplots(figsize = (30,8))
#ax.plot(Demand_plot["Date"], Demand_plot.rolling(7).sum()["Value"])
#ax.set_xticks()
#ax.set_xticklabels([i[:10] for i in Demand_plot["Date"]],rotation=90)
ax.set_title("Electricity demand before and during COVID-19 lockdown")
#ax.set_xlabel('Date')
#ax.set_ylabel('Value')
Demand_plot_smoothed=Demand_plot.rolling(7).sum()
Demand_plot_smoothed["Date"]=Demand_plot["Date"]

Demand_plot_smoothed.plot(kind='line',x='Date',y='Value',ax=ax, label = "Demand")
