# %% [markdown]
# Figure 2: Demand Evolution 2019 and 2020

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/Users/ibsi/Desktop/Ironhack/butter_team_project/sql_merged_data/final_total_co_and_dem.csv")

# %%
df=pd.DataFrame(data)
fig, ax = plt.subplots(figsize = (30,8))df
# Out:
#                     Date     CO2_type_1     CO2_type_2  Demand_value
# 0    2019-01-01 00:00:00  235253.953125  315243.250000      582950.0
# 1    2019-01-02 00:00:00  270766.468750  444379.531250      742199.0
# 2    2019-01-03 00:00:00  339102.593750  385961.750000      787765.0
# 3    2019-01-04 00:00:00  393210.625000  371368.062500      796010.0
# 4    2019-01-05 00:00:00  313972.875000  365272.937500      721030.0
# ..                   ...            ...            ...           ...
# 328  2020-06-11 00:00:00  196242.421875  476097.968750      652471.0
# 329  2020-06-12 00:00:00  160242.906250  531540.875000      649040.0
# 330  2020-06-13 00:00:00  176195.562500  454318.656250      584371.0
# 331  2020-06-14 00:00:00  195394.812500  365710.437500      544088.0
# 332  2020-06-15 00:00:00    8984.134766   12564.288086       23045.7
#
# [333 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (30,10))
ax.set_title("CO2 emmissions")
Demand_smoothed=df.rolling(7).sum()
Demand_smoothed["Date"]=df["Date"]
Demand_smoothed.plot(kind='bar',x='Date',y='CO2_type_1', ax=ax)
